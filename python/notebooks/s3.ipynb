# %%
from alphablokus.files import list_files, parse_num_games_from_filename

# %%
game_files = list_files("s3://alpha-blokus/full_v2/games/", ".bin")
total_game_count = sum(parse_num_games_from_filename(f) for f in game_files)

# %%
total_game_count
# Out:
# 10216398
