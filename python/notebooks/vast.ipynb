# %%
from vastai_sdk import VastAI
import os

vast_sdk = VastAI(api_key=os.getenv("VASTAI_API_KEY"))
offers = vast_sdk.search_offers(
    query='total_flops>20 reliability>0.99 rented=False rentable=True',
    type='on-demand',
    disable_bundling=True,
    storage=64,
    order="dph_total",
)
offers[0]
# Out:
# {'id': 28674393,
#  'ask_contract_id': 28674393,
#  'bundle_id': 1785264427,
#  'bundled_results': None,
#  'bw_nvlink': 0.0,
#  'compute_cap': 1200,
#  'cpu_arch': 'amd64',
#  'cpu_cores': 96,
#  'cpu_cores_effective': 24.0,
#  'cpu_ghz': 2.6,
#  'cpu_name': 'AMD EPYC 7K62 48-Core Processor',
#  'cpu_ram': 64394,
#  'credit_discount_max': 0.0,
#  'cuda_max_good': 12.8,
#  'direct_port_count': 124,
#  'disk_bw': 5591.390396097249,
#  'disk_name': 'GIGABYTE GP-ASM2NE6200TTTD',
#  'disk_space': 661.25,
#  'dlperf': 38.39646427068305,
#  'dlperf_per_dphtotal': 625.4627664002668,
#  'dph_base': 0.060000000000000005,
#  'dph_total': 0.061388888888888896,
#  'driver_version': '570.153.02',
#  'driver_vers': 570153002,
#  'duration': 26260408.18797183,
#  'end_date': 1796002416.0,
#  'external': None,
#  'flops_per_dphtotal': 371.10872036199083,
#  'geolocation': 'Vietnam, VN',
#  'geolocode': 1895214017,
#  'gpu_arch': 'nvidia',
#  'gpu_display_active': False,
#  'gpu_frac': 0.25,
# ...

# %%
help(vast_sdk.search_offers)
# Out:
# Help on method search_offers in module vastai.vastai_sdk:
#
# search_offers(query: Any = None, *, type: Any = 'on-demand', no_default: Any = False, new: Any = False, limit: int = None, disable_bundling: Any = False, storage: float = 5.0, order: str = 'score-') method of vastai.vastai_sdk.VastAI instance
#     Creates a query based on search parameters as in the examples above.
#
#     Query syntax:
#
#         query = comparison comparison...
#         comparison = field op value
#         field = <name of a field>
#         op = one of: <, <=, ==, !=, >=, >, in, notin
#         value = <bool, int, float, string> | 'any' | [value0, value1, ...]
#         bool: True, False
#
#     note: to pass '>' and '<' on the command line, make sure to use quotes
#     note: to encode a string query value (ie for gpu_name), replace any spaces ' ' with underscore '_'
#
#     Examples:
#
# ...

# %%
help(vast_sdk.search_offers)
# Out:
# Help on method search_offers in module vastai.vastai_sdk:
#
# search_offers(query: Any = None, *, type: Any = 'on-demand', no_default: Any = False, new: Any = False, limit: int = None, disable_bundling: Any = False, storage: float = 5.0, order: str = 'score-') method of vastai.vastai_sdk.VastAI instance
#     Creates a query based on search parameters as in the examples above.
#
#     Query syntax:
#
#         query = comparison comparison...
#         comparison = field op value
#         field = <name of a field>
#         op = one of: <, <=, ==, !=, >=, >, in, notin
#         value = <bool, int, float, string> | 'any' | [value0, value1, ...]
#         bool: True, False
#
#     note: to pass '>' and '<' on the command line, make sure to use quotes
#     note: to encode a string query value (ie for gpu_name), replace any spaces ' ' with underscore '_'
#
#     Examples:
#
# ...
